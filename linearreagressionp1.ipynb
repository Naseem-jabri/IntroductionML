# %% [markdown]
# <a href="https://colab.research.google.com/github/Naseem-jabri/IntroductionML/blob/main/linearreagressionp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***Type of ML***
#
# 1. *Supervised:*
#    1.1 Regression:
#       - 1.1.1 Linear Regression:
#          - \( f(x) = wx + b \)
#          - \( f(x) \) —> model y
#          - \( X \) —> features
#          - \( w \) —> coefficient (slope)
#          - \( b \) —> intercept
#          - Example: \( w = 1 \) and \( b = 0 \)
#          - \( f(x) = x \)
#       - 1.1.2 Nonlinear Regression:
#
# 2. *Unsupervised:*

# %%
#required libraries
import numpy as np #math fun + arrays
import pandas as pd #data (writing and struture)
import matplotlib.pyplot as plt #vesulazation

# %%
# read file
#use csv beacuse file is csv
data= pd.read_csv('/content/Salary_Data.csv')

# %%
#return data
data
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
#x is feature and y is lable
#تعيين قيم للمتغيرات

x= data['YearsExperience'].values
y= data ['Salary'].values

#returen all data in the row and put the varible
# x and y is arrays
print(x)
print(y)

#number is rows
#Two dimension is the number of rows and columns and has an index of zero=rows and one=column
print(x.shape)
print(y.shape)
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]
# (30,)
# (30,)

# %%
plt.figure(figsize=(8,6))
plt.title('data distribution')
plt.scatter(x,y)
plt.xlabel('YearsExperience') # Changed plt.x.lable to plt.xlabel
plt.ylabel('Salary') # Changed plt.y.lable to plt.ylabel
plt.show()

#The result will be a linear regression

# %% [markdown]
# *. Find Parameter \(\theta\) (slope):*
#    \[
#    \theta = \frac{y_1 - y_0}{x_1 - x_0}
#    \]
#    - Relationship between the data points:
#      \[
#      \theta = f(x_i)
#      \]
#      \[
#      f(x_i) = u x + b
#      \]
#
# *. Find Parameter \(b\):*
#    \[
#    b = \bar{y} - \theta \bar{x}
#    \]
#
# *Gradient Descent:*
#    - Find the optimal values for parameters of a differentiable function
#       - Extrema can be:
#      - Either maxima or minima
#      - Local or global
# - Using the first derivative test to find extrema values
#
# ![GG.jpg](data:image/jpeg;base64,...)

# %%
L_rate= 0.0001 #choose small value
iterations= 1000 #choose big value

#initialization (افتراض قيم ابتدائيه للثيتا)
theta_1=0
theta_0=0

#number of samples in the dataset
n= x.shape[0]

#an empty list to store the error  in each iteration
losses=[]

#The beginning of the learning process

for i in range(iterations):
  h_x= theta_0 + theta_1*x #linear equation = h(x)= theta0 + theta1 and X is an array containing YearsExperience values
  #the result will be array

  # Keeping track of the error decrease
  mse= (1/n)*np.sum((h_x -y)**2)    #n=30 and use fun sum in np
  losses.append(mse)

  #derivatives
  d_theta0= (2/n)*np.sum(h_x-y)
  d_theta1= (2/n)*np.sum(x*(h_x-y))

  #update value

theta_1= theta_1 - L_rate*d_theta1
theta_0= theta_0 - L_rate*d_theta0

# %%
print("theta_0", theta_0)
print("theta_1", theta_1)
print("MSE", mse)
# Out:
# theta_0 15.200600000000001
# theta_1 95.47974
# MSE 6502955270.733334

# %%
new_x= 5
prediction_model = theta_0 + theta_1*new_x
print("score", prediction_model)
# Out:
# score 492.5993

# %%
plt.title('loss value')
plt.plot(losses)
plt.xlabel('iteraction')
plt.ylabel('loss')
print('initial', losses[0])
print('final', losses[-1])
# Out:
# initial 6502955270.733334
# final 6502955270.733334
